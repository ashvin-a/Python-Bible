# %% [markdown]
# <a href="https://colab.research.google.com/github/ashvin-a/Python-Bible/blob/main/Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
pic = Image.open('aes1.jpg')
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1422>

# %%
pic.size
pic.filename
pic.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
kunji = pic.crop((100,800,600,1000))

# %%
pic.crop((0,0,600,1000))

# %%
pic.paste(im=kunji,box=(0,0))

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1422>

# %%
pic.resize((100,200))
# Out:
# <PIL.Image.Image image mode=RGB size=100x200>

# %%
pic.putalpha(100)
pic.save('edited.png')
